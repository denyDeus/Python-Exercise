# %%
import pandas as pd

# %%
outlet_size_small = pd.read_csv('datasets/outlet_size_small.csv')
outlet_size_medium = pd.read_csv('datasets/outlet_size_medium.csv')
outlet_size_large = pd.read_csv('datasets/outlet_size_high.csv')

# %%
outlet_size_small.shape, outlet_size_medium.shape, outlet_size_large.shape
# Out:
# ((2388, 9), (2793, 9), (932, 9))

# %%
outlet_size_small.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA03       18.500          Regular         0.045464
# 1           FDS46       17.600          Regular         0.047257
# 2           FDP49        9.000          Regular         0.069089
# 3           FDU02       13.350          Low Fat         0.102492
# 4           NCB30       14.600          Low Fat         0.025698
# 5           FDC37          NaN          Low Fat         0.057557
# 6           FDR28       13.850          Regular         0.025896
# 7           FDV10        7.645          Regular         0.066693
# 8           FDC14          NaN          Regular         0.072222
# 9           DRH01       17.500          Low Fat         0.097904
#
#       Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0         Dairy  144.1102            OUT046  Supermarket Type1
# 1   Snack Foods  119.6782            OUT046  Supermarket Type1
# ...

# %%
outlet_size_medium.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDP36       10.395          Regular         0.000000
# 4           FDP10          NaN          Low Fat         0.127470
# 5           FDY07       11.800          Low Fat         0.000000
# 6           FDX32       15.100          Regular         0.100014
# 7           NCB42       11.800          Low Fat         0.008596
# 8           FDP49        9.000          Regular         0.069196
# 9           DRI11          NaN          Low Fat         0.034238
#
#                Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                  Dairy  249.8092            OUT049  Supermarket Type1
# 1            Soft Drinks   48.2692            OUT018  Supermarket Type2
# ...

# %%
outlet_size_large.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           NCD19        8.930          Low Fat         0.000000
# 1           FDO10       13.650          Regular         0.012741
# 2           FDF32       16.350          Low Fat         0.068024
# 3           FDN22       18.850          Regular         0.138190
# 4           DRJ59       11.650          low fat         0.019356
# 5           FDK43        9.800          Low Fat         0.026818
# 6           FDL50       12.150          Regular         0.042278
# 7           FDM40       10.195          Low Fat         0.159804
# 8           FDR13        9.895          Regular         0.028697
# 9           FDL12       15.850          Regular         0.121532
#
#                Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0              Household   53.8614            OUT013  Supermarket Type1
# 1            Snack Foods   57.6588            OUT013  Supermarket Type1
# ...

# %%
all_dataframes = [outlet_size_small, outlet_size_medium, outlet_size_large]

# %%
data = pd.concat(all_dataframes, axis=0)

# %%
data.shape
# Out:
# (6113, 9)

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA03       18.500          Regular         0.045464
# 1           FDS46       17.600          Regular         0.047257
# 2           FDP49        9.000          Regular         0.069089
# 3           FDU02       13.350          Low Fat         0.102492
# 4           NCB30       14.600          Low Fat         0.025698
# 5           FDC37          NaN          Low Fat         0.057557
# 6           FDR28       13.850          Regular         0.025896
# 7           FDV10        7.645          Regular         0.066693
# 8           FDC14          NaN          Regular         0.072222
# 9           DRH01       17.500          Low Fat         0.097904
#
#       Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0         Dairy  144.1102            OUT046  Supermarket Type1
# 1   Snack Foods  119.6782            OUT046  Supermarket Type1
# ...

# %%
sample_dataframe = pd.DataFrame({
    'roll_no' : [102, 101, 104, 103, 105],
    'name' : ['Denis', 'Stella', 'Winfrida', 'Deus', 'Suzana'],
    'grade' : ['A', 'B', 'A', 'C', 'C'],
    'marks' : [25, 19, 22, 10, 13],
    'city' : ['Ubungo', 'Masasi', 'Pwani', 'Temeke', 'Kigamboni']
})

sample_dataframe
# Out:
#    roll_no      name grade  marks       city
# 0      102     Denis     A     25     Ubungo
# 1      101    Stella     B     19     Masasi
# 2      104  Winfrida     A     22      Pwani
# 3      103      Deus     C     10     Temeke
# 4      105    Suzana     C     13  Kigamboni

# %%
phone_no = pd.DataFrame({'phone_no' : [212202, 202021, 212334, 213431, 211721]})

phone_no
# Out:
#    phone_no
# 0    212202
# 1    202021
# 2    212334
# 3    213431
# 4    211721

# %%
combined = pd.concat([sample_dataframe, phone_no], axis=1)

combined
# Out:
#    roll_no      name grade  marks       city  phone_no
# 0      102     Denis     A     25     Ubungo    212202
# 1      101    Stella     B     19     Masasi    202021
# 2      104  Winfrida     A     22      Pwani    212334
# 3      103      Deus     C     10     Temeke    213431
# 4      105    Suzana     C     13  Kigamboni    211721
