# %%
cars = ["Ford", "Volvo", "BMW"]

x = cars[0]

print(x)
# Out:
# Ford

# %%
cars = ["Ford", "Volvo", "BMW"]

x = cars[0]
cars[0] = "Toyota"

print(cars)
# Out:
# ['Toyota', 'Volvo', 'BMW']

# %%
cars = ["Ford", "Volvo", "BMW"]

x = len(cars)

print(x)
# Out:
# 3

# %%
cars = ["Ford", "Volvo", "BMW"]

for x in cars:
    print(x)
# Out:
# Ford
# Volvo
# BMW

# %%
cars = ["Ford", "Volvo", "BMW"]

cars.append("Honda")

print(cars)
# Out:
# ['Ford', 'Volvo', 'BMW', 'Honda']

# %%
cars = ["Ford", "Volvo", "BMW"]

cars.pop(1)

print(cars)
# Out:
# ['Ford', 'BMW']

# %%
cars = ["Ford", "Volvo", "BMW"]

cars.remove("Volvo")

print(cars)
# Out:
# ['Ford', 'BMW']
