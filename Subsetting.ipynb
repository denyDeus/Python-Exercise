# %%
import pandas as pd

# %%
data = pd.read_csv('global_disaster_response_2018_2024.csv')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %%
data.shape
# Out:
# (50000, 12)

# %%
data.columns
# Out:
# Index(['date', 'country', 'disaster_type', 'severity_index', 'casualties',
#        'economic_loss_usd', 'response_time_hours', 'aid_amount_usd',
#        'response_efficiency_score', 'recovery_days', 'latitude', 'longitude'],
#       dtype='object')

# %%
data.head(100)
# Out:
#              date        country      disaster_type  severity_index  \
# 2063   2021-01-31         Brazil         Earthquake            5.99
# 37397  2018-12-23         Brazil       Extreme Heat            6.53
# 31487  2020-08-10          India          Hurricane            1.55
# 18620  2022-09-15      Indonesia       Extreme Heat            4.55
# 7868   2022-09-28  United States           Wildfire            3.80
# ...           ...            ...                ...             ...
# 27941  2018-10-26     Bangladesh        Storm Surge            5.21
# 9100   2022-04-22        Nigeria          Hurricane            4.31
# 24661  2022-10-08  United States              Flood            7.54
# 37725  2018-07-25          Chile  Volcanic Eruption            4.52
# 6994   2019-07-01         Brazil  Volcanic Eruption            6.23
#
#        casualties  economic_loss_usd  response_time_hours  aid_amount_usd  \
# 2063          111         7934365.71                15.62       271603.79
# ...

# %%
import random

random_list = [random.randint(1, 50000) for i in range(50000)]

# %%
random_list
# Out:
# [2063,
#  37397,
#  31487,
#  18620,
#  7868,
#  26870,
#  17619,
#  24297,
#  32127,
#  24203,
#  31006,
#  37575,
#  13893,
#  48236,
#  38501,
#  19332,
#  10672,
#  17001,
#  37479,
#  1340,
#  38647,
#  12002,
#  22622,
#  34087,
#  5131,
#  47658,
#  6394,
#  35384,
#  46109,
#  13102,
#  4348,
#  42369,
#  7092,
#  627,
#  15878,
#  46199,
#  22288,
#  10423,
#  29929,
#  25292,
#  45953,
#  39635,
#  43804,
#  25347,
#  2354,
#  32542,
#  37912,
#  24372,
#  8590,
#  25523,
#  20913,
#  12586,
#  3240,
#  40670,
#  44527,
#  29810,
#  25409,
#  10113,
#  16280,
#  28840,
#  2675,
#  1643,
#  20968,
#  13275,
#  6391,
#  43449,
#  37988,
#  28664,
#  20979,
#  19632,
#  48421,
#  15682,
#  24255,
#  3259,
#  39721,
#  645,
#  7509,
#  29369,
#  29804,
#  46187,
#  14989,
#  30772,
#  45847,
#  34982,
#  37248,
#  5253,
#  11997,
#  44644,
#  34263,
#  6820,
#  3141,
#  18109,
#  1825,
#  33616,
#  33162,
#  27941,
#  9100,
#  24661,
#  37725,
#  6994,
#  3067,
#  37187,
# ...

# %%
data.index = random_list

# %%
data.head(100)
# Out:
#              date        country      disaster_type  severity_index  \
# 2063   2021-01-31         Brazil         Earthquake            5.99
# 37397  2018-12-23         Brazil       Extreme Heat            6.53
# 31487  2020-08-10          India          Hurricane            1.55
# 18620  2022-09-15      Indonesia       Extreme Heat            4.55
# 7868   2022-09-28  United States           Wildfire            3.80
# ...           ...            ...                ...             ...
# 27941  2018-10-26     Bangladesh        Storm Surge            5.21
# 9100   2022-04-22        Nigeria          Hurricane            4.31
# 24661  2022-10-08  United States              Flood            7.54
# 37725  2018-07-25          Chile  Volcanic Eruption            4.52
# 6994   2019-07-01         Brazil  Volcanic Eruption            6.23
#
#        casualties  economic_loss_usd  response_time_hours  aid_amount_usd  \
# 2063          111         7934365.71                15.62       271603.79
# ...

# %%
data = pd.read_csv('global_disaster_response_2018_2024.csv')

data.set_index('casualties', drop=True, inplace=True)

# %%
data.head(100)
# Out:
#                   date        country      disaster_type  severity_index  \
# casualties
# 111         2021-01-31         Brazil         Earthquake            5.99
# 100         2018-12-23         Brazil       Extreme Heat            6.53
# 22          2020-08-10          India          Hurricane            1.55
# 94          2022-09-15      Indonesia       Extreme Heat            4.55
# 64          2022-09-28  United States           Wildfire            3.80
# ...                ...            ...                ...             ...
# 90          2018-10-26     Bangladesh        Storm Surge            5.21
# 70          2022-04-22        Nigeria          Hurricane            4.31
# 205         2022-10-08  United States              Flood            7.54
# 73          2018-07-25          Chile  Volcanic Eruption            4.52
# 161         2019-07-01         Brazil  Volcanic Eruption            6.23
#
#             economic_loss_usd  response_time_hours  aid_amount_usd  \
# ...

# %%
data.index
# Out:
# Index([111, 100,  22,  94,  64,  56,  81,  34,  56,  73,
#        ...
#         51,  54,   6,   1, 182,  78, 165, 130,  82, 129],
#       dtype='int64', name='casualties', length=50000)
