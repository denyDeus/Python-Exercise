# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/big_mart_sales.csv')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
import random

random_list = [random.randint(1, 8523) for i in range(8523)]

# %%
random_list
# Out:
# [7578,
#  5785,
#  2217,
#  3193,
#  6038,
#  4311,
#  2538,
#  2817,
#  3711,
#  2628,
#  7856,
#  7019,
#  3430,
#  3431,
#  982,
#  2362,
#  2668,
#  3855,
#  6900,
#  6709,
#  6623,
#  8421,
#  4464,
#  8409,
#  6715,
#  5139,
#  8013,
#  238,
#  4860,
#  1422,
#  5925,
#  478,
#  6171,
#  4539,
#  4742,
#  5,
#  147,
#  4151,
#  7230,
#  1472,
#  3141,
#  4475,
#  4553,
#  508,
#  8263,
#  5267,
#  8404,
#  2036,
#  6579,
#  4614,
#  6941,
#  4897,
#  1951,
#  3432,
#  6160,
#  47,
#  1149,
#  394,
#  7643,
#  1304,
#  125,
#  1094,
#  5891,
#  5537,
#  4805,
#  764,
#  1575,
#  2423,
#  7040,
#  787,
#  5307,
#  4220,
#  8282,
#  6581,
#  2,
#  6139,
#  3490,
#  4604,
#  521,
#  8322,
#  4418,
#  7501,
#  1483,
#  3270,
#  5465,
#  2104,
#  5127,
#  4731,
#  4948,
#  7291,
#  5121,
#  4331,
#  6773,
#  4644,
#  7133,
#  3053,
#  2527,
#  3995,
#  4274,
#  5733,
#  5464,
#  3947,
#  2200,
#  2493,
#  7336,
#  2745,
#  7081,
#  4353,
#  2004,
#  1766,
#  1417,
#  7525,
#  8040,
#  7527,
#  821,
#  5424,
#  8017,
#  4369,
#  3680,
#  3489,
#  2457,
#  3729,
#  5540,
#  3984,
#  2938,
#  5195,
#  7197,
#  6191,
#  948,
#  5736,
#  6452,
#  2614,
#  3847,
#  3166,
#  7599,
#  1643,
#  2222,
#  1789,
#  8347,
#  8051,
#  6981,
#  2748,
#  5955,
#  1387,
#  679,
#  7182,
#  5834,
#  5722,
#  3891,
#  5616,
#  2499,
#  2397,
#  4038,
#  5602,
#  4766,
#  412,
#  1347,
#  3079,
#  797,
#  3901,
#  620,
#  6400,
#  8498,
#  1473,
#  293,
#  5052,
#  1994,
#  988,
#  3471,
#  4639,
#  7027,
#  619,
#  6902,
#  6852,
#  397,
#  6122,
#  184,
#  2514,
#  1516,
#  1539,
#  5340,
#  1843,
#  3113,
#  7490,
#  1361,
#  4742,
#  3673,
#  4445,
#  3613,
#  5984,
#  2634,
#  3861,
#  4301,
#  6716,
#  4659,
#  3598,
#  7520,
#  8298,
#  682,
#  1297,
#  4672,
#  7948,
#  5199,
#  3514,
#  4475,
#  3799,
#  6119,
#  8163,
#  8405,
#  5577,
#  3945,
#  1711,
#  2488,
#  2836,
#  4215,
#  5696,
#  419,
#  2283,
#  1442,
#  8483,
#  8331,
#  3393,
#  6765,
#  736,
#  2047,
#  3709,
#  788,
#  2241,
#  6794,
#  442,
#  2448,
#  8327,
#  2886,
#  5354,
#  3114,
#  1011,
#  1133,
#  7506,
#  5653,
#  7819,
#  1418,
#  8396,
#  5804,
#  4122,
#  8176,
#  1518,
#  7281,
#  7197,
#  4527,
#  7751,
#  7310,
#  506,
#  1180,
#  5129,
#  1236,
#  1980,
#  8386,
#  7449,
#  7126,
#  1023,
#  683,
#  5409,
#  1875,
#  4794,
#  3565,
#  46,
#  5950,
#  6042,
#  5447,
#  875,
#  4194,
#  7223,
#  7020,
#  4698,
#  13,
#  824,
#  3504,
#  6482,
#  3025,
#  1397,
#  1162,
#  8347,
#  7508,
#  6921,
#  7071,
#  2071,
#  6763,
#  2508,
#  4466,
#  3085,
#  1911,
#  4576,
#  8079,
#  3981,
#  6526,
#  3706,
#  4740,
#  2127,
#  7376,
#  361,
#  2842,
#  2613,
#  815,
#  1022,
#  5336,
#  739,
#  6907,
#  3426,
#  1482,
#  1583,
#  3812,
#  5518,
#  181,
#  265,
#  7409,
#  2663,
#  2476,
#  6003,
#  3578,
#  249,
#  8148,
#  2485,
#  473,
#  7791,
#  2103,
#  6067,
#  6347,
#  5423,
#  601,
#  2289,
#  8059,
#  1204,
#  4744,
#  380,
#  7918,
#  7239,
#  2572,
#  6608,
#  931,
#  4257,
#  4827,
#  4252,
#  805,
#  4087,
#  1563,
#  2471,
#  4427,
#  6300,
#  1056,
#  1711,
#  2843,
#  5023,
#  3354,
#  497,
#  7431,
#  1466,
#  5989,
#  7671,
#  184,
#  8207,
#  8512,
#  6365,
#  2977,
#  79,
#  1902,
#  7964,
#  61,
#  1238,
#  7802,
#  4599,
#  4701,
#  2136,
#  7969,
#  3094,
#  5405,
#  934,
#  5290,
#  5025,
#  3808,
#  7146,
#  2533,
#  3051,
#  5535,
#  7180,
#  7266,
#  5721,
#  2195,
#  6243,
#  7348,
#  6462,
#  4633,
#  7110,
#  8204,
#  1592,
#  4375,
#  2779,
#  5106,
#  7095,
#  6926,
#  1698,
#  7050,
#  1795,
#  7031,
#  8338,
#  1376,
#  4302,
#  7473,
#  7594,
#  4109,
#  5775,
#  6161,
#  8428,
#  756,
#  5501,
#  3349,
#  6237,
#  995,
#  5315,
#  575,
#  1736,
#  4726,
#  199,
#  4516,
#  3476,
#  121,
#  388,
#  5134,
#  3056,
#  1325,
#  935,
#  1660,
#  7114,
#  16,
#  1147,
#  8495,
#  7001,
#  871,
#  6306,
#  4814,
#  782,
#  7355,
#  789,
#  3032,
#  2945,
#  2158,
#  7584,
#  2513,
#  2864,
#  3600,
#  3499,
#  7583,
#  3713,
#  4584,
#  5454,
#  6936,
#  4475,
#  3044,
#  4766,
#  2383,
#  6685,
#  4049,
#  2881,
#  5387,
#  707,
#  5684,
#  7746,
#  948,
#  975,
#  7455,
#  4208,
#  4350,
#  8315,
#  78,
#  4326,
#  1564,
#  2535,
#  1712,
#  7754,
#  8393,
#  1055,
#  573,
#  7275,
#  2345,
#  8146,
#  4988,
#  3671,
#  3583,
#  6572,
#  8307,
#  8258,
#  7036,
#  727,
#  5641,
#  752,
#  1867,
#  5082,
#  4198,
#  1678,
#  5169,
#  5052,
#  1187,
#  1714,
#  8374,
#  6559,
#  8493,
#  2757,
#  6738,
#  1420,
#  6817,
#  90,
#  3925,
#  7022,
#  1308,
#  6651,
#  8246,
#  6710,
#  5290,
#  1286,
#  1652,
#  3313,
#  7069,
#  3021,
#  7016,
#  3016,
#  4287,
#  1298,
#  7090,
#  3688,
#  5634,
#  621,
#  6683,
#  5435,
#  6881,
#  4121,
#  5226,
#  4243,
#  3530,
#  3056,
#  2807,
#  3151,
#  1148,
#  6635,
#  6315,
#  8378,
#  1563,
#  6162,
#  8006,
#  7925,
#  4124,
#  891,
#  7161,
#  1202,
#  5107,
#  1850,
#  8052,
#  8439,
#  5832,
#  531,
#  1059,
#  4335,
#  91,
#  3141,
#  3497,
#  694,
#  594,
#  7402,
#  6149,
#  6638,
#  3150,
#  775,
#  4771,
#  8428,
#  7108,
#  7168,
#  3252,
#  346,
#  6698,
#  382,
#  1426,
#  4442,
#  3967,
#  7843,
#  2999,
#  5960,
#  3420,
#  7970,
#  1507,
#  352,
#  568,
#  720,
#  3954,
#  5660,
#  1640,
#  7251,
#  2036,
#  7064,
#  5148,
#  387,
#  7348,
#  22,
#  1432,
#  457,
#  4430,
#  1004,
#  8415,
#  4297,
#  6203,
#  5988,
#  6725,
#  700,
#  7579,
#  3534,
#  4041,
#  6358,
#  2441,
#  7567,
#  7685,
#  8015,
#  1512,
#  3014,
#  988,
#  6763,
#  8173,
#  487,
#  6930,
#  794,
#  2353,
#  4117,
#  3947,
#  1389,
#  735,
#  1885,
#  4573,
#  5232,
#  4415,
#  6021,
#  8316,
#  1804,
#  2119,
#  6030,
#  8393,
#  5599,
#  5184,
#  3357,
#  2984,
#  7065,
#  6822,
#  8076,
#  4620,
#  2981,
#  1700,
#  568,
#  665,
#  6287,
#  8394,
#  2294,
#  3726,
#  7556,
#  498,
#  2574,
#  2241,
#  8296,
#  3400,
#  2814,
#  4304,
#  7133,
#  7390,
#  2199,
#  6966,
#  6784,
#  6020,
#  3815,
#  7336,
#  3881,
#  8216,
#  1232,
#  4843,
#  7007,
#  7196,
#  4763,
#  7553,
#  6672,
#  3520,
#  4358,
#  5775,
#  2900,
#  5528,
#  5193,
#  2961,
#  6011,
#  1383,
#  4930,
#  8457,
#  2175,
#  1151,
#  6603,
#  5115,
#  5655,
#  897,
#  614,
#  7136,
#  7345,
#  334,
#  329,
#  8097,
#  5084,
#  7615,
#  6585,
#  3487,
#  3255,
#  3174,
#  2312,
#  4884,
#  8122,
#  6610,
#  2359,
#  6053,
#  5106,
#  3891,
#  679,
#  3828,
#  1976,
#  5381,
#  578,
#  4074,
#  2353,
#  7610,
#  2550,
#  5959,
#  6610,
#  7643,
#  7510,
#  6635,
#  2240,
#  1301,
#  6580,
#  71,
#  6270,
#  5585,
#  4274,
#  5981,
#  6183,
#  7383,
#  5567,
#  7411,
#  1279,
#  3285,
#  6009,
#  4104,
#  7209,
#  1218,
#  6276,
#  7434,
#  3900,
#  7219,
#  4018,
#  488,
#  6076,
#  7247,
#  6346,
#  7291,
#  4718,
#  1407,
#  6181,
#  6178,
#  689,
#  4328,
#  2918,
#  3971,
#  6208,
#  4226,
#  6518,
#  7190,
#  1917,
#  3420,
#  1473,
#  981,
#  2377,
#  3522,
#  1582,
#  672,
#  2772,
#  3511,
#  5971,
#  5440,
#  7304,
#  6186,
#  8041,
#  2705,
#  1986,
#  1308,
#  4708,
#  7440,
#  928,
#  254,
#  7516,
#  1070,
#  960,
#  7438,
#  4988,
#  206,
#  4587,
#  3705,
#  1282,
#  5183,
#  4172,
#  1241,
#  4850,
#  6711,
#  935,
#  5878,
#  8321,
#  5092,
#  63,
#  5566,
#  7934,
#  5552,
#  769,
#  8367,
#  4394,
#  5077,
#  6139,
#  3895,
#  7797,
#  7087,
#  6088,
#  7268,
#  2935,
#  403,
#  5583,
#  3818,
#  6508,
#  8022,
#  1204,
#  790,
#  7917,
#  5959,
#  7672,
#  1219,
#  3793,
#  5567,
#  4866,
#  3116,
#  7951,
#  1517,
#  4557,
#  6017,
#  4552,
#  4093,
#  6535,
#  3439,
#  3960,
#  7164,
#  6563,
#  4180,
#  6314,
#  7294,
#  1854,
#  8238,
#  6938,
#  7344,
#  2134,
#  3913,
#  4183,
#  4518,
#  2146,
#  1895,
#  1169,
#  2729,
#  4084,
#  746,
#  4495,
#  5578,
#  6006,
#  3975,
#  2009,
#  8106,
#  7773,
#  7675,
#  6755,
#  4551,
#  7825,
#  5637,
#  1933,
#  1056,
#  2848,
#  6124,
#  5738,
#  3721,
#  1413,
#  3929,
#  3844,
#  1377,
#  7281,
#  98,
#  1283,
#  959,
#  1299,
#  5890,
#  4281,
#  4423,
#  6590,
#  2631,
#  54,
#  1825,
#  7837,
#  7667,
#  6885,
#  1797,
#  1885,
#  6113,
#  688,
#  4935,
#  8337,
#  6196,
#  5239,
#  4986,
#  7227,
#  7582,
#  4784,
#  7713,
#  3210,
#  5843,
#  3741,
#  3042,
#  3680,
#  6378,
#  7978,
#  1829,
#  2466,
#  7269,
#  4190,
#  3293,
#  3,
#  5318,
#  4960,
#  6645,
#  5843,
#  1195,
#  2575,
#  6493,
#  3588,
#  5796,
#  8499,
#  7418,
#  1492,
#  4819,
#  2775,
#  6629,
#  6297,
#  880,
#  5691,
#  2548,
#  3671,
#  6551,
#  8235,
#  772,
#  1660,
#  5138,
#  1309,
#  8490,
#  7683,
#  7747,
#  961,
#  2983,
#  1131,
#  3906,
#  2118,
#  4205,
#  4901,
#  7751,
#  4492,
#  6036,
#  2244,
#  3403,
#  2367,
#  199,
#  4887,
#  5699,
#  1026,
#  746,
#  2835,
#  8204,
#  8316,
#  2154,
#  3750,
#  8295,
#  3076,
#  3648,
#  3023,
#  6866,
#  3611,
#  4691,
#  5675,
#  3040,
#  1723,
#  8090,
#  3325,
#  3161,
#  1678,
#  ...]

# %%
data.index = random_list

# %%
data.head(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7578           FDA15        9.300          Low Fat         0.016047
# 5785           DRC01        5.920          Regular         0.019278
# 2217           FDN15       17.500          Low Fat         0.016760
# 3193           FDX07       19.200          Regular         0.000000
# 6038           NCD19        8.930          Low Fat         0.000000
# 4311           FDP36       10.395          Regular         0.000000
# 2538           FDO10       13.650          Regular         0.012741
# 2817           FDP10          NaN          Low Fat         0.127470
# 3711           FDH17       16.200          Regular         0.016687
# 2628           FDU28       19.200          Regular         0.094450
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7578                  Dairy  249.8092            OUT049
# 5785            Soft Drinks   48.2692            OUT018
# 2217                   Meat  141.6180            OUT049
# 3193  Fruits and Vegetables  182.0950            OUT010
# 6038              Household   53.8614            OUT013
# 4311           Baking Goods   51.4008            OUT018
# 2538            Snack Foods   57.6588            OUT013
# 2817            Snack Foods  107.7622            OUT027
# 3711           Frozen Foods   96.9726            OUT045
# 2628           Frozen Foods  187.8214            OUT017
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7578                       1999      Medium               Tier 1
# 5785                       2009      Medium               Tier 3
# 2217                       1999      Medium               Tier 1
# 3193                       1998         NaN               Tier 3
# 6038                       1987        High               Tier 3
# 4311                       2009      Medium               Tier 3
# 2538                       1987        High               Tier 3
# 2817                       1985      Medium               Tier 3
# 3711                       2002         NaN               Tier 2
# 2628                       2007         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 7578  Supermarket Type1          3735.1380
# 5785  Supermarket Type2           443.4228
# 2217  Supermarket Type1          2097.2700
# 3193      Grocery Store           732.3800
# 6038  Supermarket Type1           994.7052
# 4311  Supermarket Type2           556.6088
# 2538  Supermarket Type1           343.5528
# 2817  Supermarket Type3          4022.7636
# 3711  Supermarket Type1          1076.5986
# 2628  Supermarket Type1          4710.5350

# %%
data.head(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7578           FDA15        9.300          Low Fat         0.016047
# 5785           DRC01        5.920          Regular         0.019278
# 2217           FDN15       17.500          Low Fat         0.016760
# 3193           FDX07       19.200          Regular         0.000000
# 6038           NCD19        8.930          Low Fat         0.000000
# 4311           FDP36       10.395          Regular         0.000000
# 2538           FDO10       13.650          Regular         0.012741
# 2817           FDP10          NaN          Low Fat         0.127470
# 3711           FDH17       16.200          Regular         0.016687
# 2628           FDU28       19.200          Regular         0.094450
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7578                  Dairy  249.8092            OUT049
# 5785            Soft Drinks   48.2692            OUT018
# 2217                   Meat  141.6180            OUT049
# 3193  Fruits and Vegetables  182.0950            OUT010
# 6038              Household   53.8614            OUT013
# 4311           Baking Goods   51.4008            OUT018
# 2538            Snack Foods   57.6588            OUT013
# 2817            Snack Foods  107.7622            OUT027
# 3711           Frozen Foods   96.9726            OUT045
# 2628           Frozen Foods  187.8214            OUT017
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7578                       1999      Medium               Tier 1
# 5785                       2009      Medium               Tier 3
# 2217                       1999      Medium               Tier 1
# 3193                       1998         NaN               Tier 3
# 6038                       1987        High               Tier 3
# 4311                       2009      Medium               Tier 3
# 2538                       1987        High               Tier 3
# 2817                       1985      Medium               Tier 3
# 3711                       2002         NaN               Tier 2
# 2628                       2007         NaN               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales
# 7578  Supermarket Type1          3735.1380
# 5785  Supermarket Type2           443.4228
# 2217  Supermarket Type1          2097.2700
# 3193      Grocery Store           732.3800
# 6038  Supermarket Type1           994.7052
# 4311  Supermarket Type2           556.6088
# 2538  Supermarket Type1           343.5528
# 2817  Supermarket Type3          4022.7636
# 3711  Supermarket Type1          1076.5986
# 2628  Supermarket Type1          4710.5350

# %%
data = pd.read_csv('datasets/big_mart_sales.csv')

data.set_index('Outlet_Establishment_Year', drop=True, inplace=False)
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15        9.300          Low Fat
# 2009                                DRC01        5.920          Regular
# 1999                                FDN15       17.500          Low Fat
# 1998                                FDX07       19.200          Regular
# 1987                                NCD19        8.930          Low Fat
# ...                                   ...          ...              ...
# 1987                                FDF22        6.865          Low Fat
# 2002                                FDS36        8.380          Regular
# 2004                                NCJ29       10.600          Low Fat
# 2009                                FDN46        7.210          Regular
# 1997                                DRG01       14.800          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
# ...                                    ...                    ...       ...
# 1987                              0.056783            Snack Foods  214.5218
# 2002                              0.046982           Baking Goods  108.1570
# 2004                              0.035186     Health and Hygiene   85.1224
# 2009                              0.145221            Snack Foods  103.1332
# 1997                              0.044878            Soft Drinks   75.4670
#
#                           Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Outlet_Establishment_Year
# 1999                                 OUT049      Medium               Tier 1
# 2009                                 OUT018      Medium               Tier 3
# 1999                                 OUT049      Medium               Tier 1
# 1998                                 OUT010         NaN               Tier 3
# 1987                                 OUT013        High               Tier 3
# ...                                     ...         ...                  ...
# 1987                                 OUT013        High               Tier 3
# 2002                                 OUT045         NaN               Tier 2
# 2004                                 OUT035       Small               Tier 2
# 2009                                 OUT018      Medium               Tier 3
# 1997                                 OUT046       Small               Tier 1
#
#                                  Outlet_Type  Item_Outlet_Sales
# Outlet_Establishment_Year
# 1999                       Supermarket Type1          3735.1380
# 2009                       Supermarket Type2           443.4228
# 1999                       Supermarket Type1          2097.2700
# 1998                           Grocery Store           732.3800
# 1987                       Supermarket Type1           994.7052
# ...                                      ...                ...
# 1987                       Supermarket Type1          2778.3834
# 2002                       Supermarket Type1           549.2850
# 2004                       Supermarket Type1          1193.1136
# 2009                       Supermarket Type2          1845.5976
# 1997                       Supermarket Type1           765.6700
#
# [8523 rows x 11 columns]

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
data.tail(10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8513                Meat   99.9042            OUT035
# 8514              Canned   57.5904            OUT045
# 8515        Baking Goods  157.5288            OUT018
# 8516              Others   58.7588            OUT018
# 8517        Frozen Foods  178.8318            OUT046
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8513                       2004       Small               Tier 2
# 8514                       2002         NaN               Tier 2
# 8515                       2009      Medium               Tier 3
# 8516                       2009      Medium               Tier 3
# 8517                       1997       Small               Tier 1
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 8513  Supermarket Type1           595.2252
# 8514  Supermarket Type1           468.7232
# 8515  Supermarket Type2          1571.2880
# 8516  Supermarket Type2           858.8820
# 8517  Supermarket Type1          3608.6360
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700

# %%
data[10:15:2]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDY07        11.80          Low Fat         0.000000
# 12           FDX32        15.10          Regular         0.100014
# 14           FDF32        16.35          Low Fat         0.068024
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 10  Fruits and Vegetables   45.5402            OUT049
# 12  Fruits and Vegetables  145.4786            OUT049
# 14  Fruits and Vegetables  196.4426            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 10                       1999      Medium               Tier 1
# 12                       1999      Medium               Tier 1
# 14                       1987        High               Tier 3
#
#           Outlet_Type  Item_Outlet_Sales
# 10  Supermarket Type1          1516.0266
# 12  Supermarket Type1          1589.2646
# 14  Supermarket Type1          1977.4260

# %%
data.iloc[[1, 7, 3, 5, 0]]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1           DRC01        5.920          Regular         0.019278
# 7           FDP10          NaN          Low Fat         0.127470
# 3           FDX07       19.200          Regular         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 0           FDA15        9.300          Low Fat         0.016047
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# 7            Snack Foods  107.7622            OUT027
# 3  Fruits and Vegetables  182.0950            OUT010
# 5           Baking Goods   51.4008            OUT018
# 0                  Dairy  249.8092            OUT049
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1                       2009      Medium               Tier 3
# 7                       1985      Medium               Tier 3
# 3                       1998         NaN               Tier 3
# 5                       2009      Medium               Tier 3
# 0                       1999      Medium               Tier 1
#
#          Outlet_Type  Item_Outlet_Sales
# 1  Supermarket Type2           443.4228
# 7  Supermarket Type3          4022.7636
# 3      Grocery Store           732.3800
# 5  Supermarket Type2           556.6088
# 0  Supermarket Type1          3735.1380

# %%
data.iloc[[1, 7, 3, 5, 0], [2, 6, 4, 8, 0]]
# Out:
#   Item_Fat_Content Outlet_Identifier              Item_Type Outlet_Size  \
# 1          Regular            OUT018            Soft Drinks      Medium
# 7          Low Fat            OUT027            Snack Foods      Medium
# 3          Regular            OUT010  Fruits and Vegetables         NaN
# 5          Regular            OUT018           Baking Goods      Medium
# 0          Low Fat            OUT049                  Dairy      Medium
#
#   Item_Identifier
# 1           DRC01
# 7           FDP10
# 3           FDX07
# 5           FDP36
# 0           FDA15
