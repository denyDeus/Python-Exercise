# %%
#Selecting all records from the customers table, and display the result.
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# ('Denis', 'Highway 21', 1)
# ('Denis', 'Mbagala', 2)
# ('Grace', 'Changanyikeni', 3)
# ('Eldon', 'Msewe', 4)
# ('Juma', 'Golani', 5)
# ('Emmanuel', 'Tegeta', 6)
# ('Greyson', 'Boko', 7)
# ('Sara', 'Makongo', 8)
# ('Abby', 'Goba', 9)
# ('Veronica', 'Wazo', 10)
# ('Mganga', 'Chanika', 11)
# ('Alinamaka', 'Hall 2', 12)
# ('Ally', 'Hall 5', 13)
# ('Stella', 'Highway 14', 14)

# %%
#selecting only the name and address columns
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT name, address FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# ('Denis', 'Highway 21')
# ('Denis', 'Mbagala')
# ('Grace', 'Changanyikeni')
# ('Eldon', 'Msewe')
# ('Juma', 'Golani')
# ('Emmanuel', 'Tegeta')
# ('Greyson', 'Boko')
# ('Sara', 'Makongo')
# ('Abby', 'Goba')
# ('Veronica', 'Wazo')
# ('Mganga', 'Chanika')
# ('Alinamaka', 'Hall 2')
# ('Ally', 'Hall 5')
# ('Stella', 'Highway 14')

# %%
#Fetch only one row
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchone()


print(myresult)
# Out:
# ('Denis', 'Highway 21', 1)

# %%
#Selecting all records where the address is Msewe
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM customers WHERE address = 'Msewe'"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# ('Eldon', 'Msewe', 4)
