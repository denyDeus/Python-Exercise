# %%
#Connecting and Creating database
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#"
    )

print("Connected successfully")
# Out:
# Connected successfully

# %%
#Return a list of system's database
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
    print(x)
# Out:
# ('company',)
# ('global_disaster_response_2018_2024',)
# ('information_schema',)
# ('mydatabase',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
#Trying to connect to database'mydatabase'
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

# %%
#Creating a table named customers
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[5], line 13
#       4 mydb = mysql.connector.connect(
#       5     host = "localhost",
#       6     user = "root",
#       7     passwd = "@denis_13#",
#       8     database = "mydatabase"
#       9 )
#      11 mycursor = mydb.cursor()
# ---> 13 mycursor.execute("CREATE TABLE customers (name VARCHAR(255), address VARCHAR(255))")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\cursor.py:416, in MySQLCursor.execute(self, operation, params, map_results)
#     408 self._executed_list = self._stmt_partition["single_stmts"]
#     409 self._executed = (
#     410     self._stmt_partition["single_stmts"].popleft()
#     411     if map_results
#     412     else self._stmt_partition["mappable_stmt"]
#     413 )
#     415 self._handle_result(
# --> 416     self._connection.cmd_query(
#     417         self._stmt_partition["mappable_stmt"],
#     418         read_timeout=self._read_timeout,
#     419         write_timeout=self._write_timeout,
#     420     )
#     421 )
#     423 return None
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\_decorating.py:89, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      87 if isinstance(err, TimeoutError):
#      88     cnx.close()
# ---> 89 raise err
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\_decorating.py:85, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      80 @functools.wraps(cnx_method)
#      81 def handle_cnx_method(
#      82     cnx: "MySQLConnectionAbstract", *args: Any, **kwargs: Any
#      83 ) -> Any:
#      84     try:
# ---> 85         return cnx_method(cnx, *args, **kwargs)
#      86     except Exception as err:
#      87         if isinstance(err, TimeoutError):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\connection.py:984, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     981     read_timeout = kwargs.get("read_timeout", None)
#     982     write_timeout = kwargs.get("write_timeout", None)
# --> 984     result = self._handle_result(
#     985         self._send_cmd(
#     986             ServerCmd.QUERY,
#     987             query,
#     988             read_timeout=read_timeout,
#     989             write_timeout=write_timeout,
#     990         ),
#     991         read_timeout,
#     992         write_timeout,
#     993     )
#     994 except ProgrammingError as err:
#     995     if err.errno == 3948 and "Loading local data is disabled" in err.msg:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\_decorating.py:89, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      87 if isinstance(err, TimeoutError):
#      88     cnx.close()
# ---> 89 raise err
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\_decorating.py:85, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      80 @functools.wraps(cnx_method)
#      81 def handle_cnx_method(
#      82     cnx: "MySQLConnectionAbstract", *args: Any, **kwargs: Any
#      83 ) -> Any:
#      84     try:
# ---> 85         return cnx_method(cnx, *args, **kwargs)
#      86     except Exception as err:
#      87         if isinstance(err, TimeoutError):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mysql\connector\connection.py:745, in MySQLConnection._handle_result(self, packet, read_timeout, write_timeout)
#     743     return self._handle_eof(packet)
#     744 if packet[4] == ERR_STATUS:
# --> 745     raise get_exception(packet)
#     747 # We have a text result set
#     748 column_count = self._protocol.parse_column_count(packet)
#
# ProgrammingError: 1050 (42S01): Table 'customers' already exists

# %%
#Return a list of tables
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

mycursor.execute("SHOW TABLES")

for x in mycursor:
    print(x)
# Out:
# ('customers',)
