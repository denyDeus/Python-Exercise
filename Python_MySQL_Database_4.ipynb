# %%
#Delete any record where the address is "Mbagala"
import mysql.connector

mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

sql = "DELETE FROM customers WHERE address = 'Mbagala'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
#Escape values by using the placeholder %s method
import mysql.connector

mydb = mysql.connector.connect(
     host = "localhost",
    user = "root",
    passwd = "@denis_13#",
    database = "mydatabase"
)

mycursor = mydb.cursor()

sql = "DELETE FROM customers WHERE address = %s"
adr = ("Mbagala", )

mycursor.execute(sql, adr)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 0 record(s) deleted
