# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/big_mart_sales.csv')

# %%
data.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 5           Baking Goods   51.4008            OUT018
# 6            Snack Foods   57.6588            OUT013
# 7            Snack Foods  107.7622            OUT027
# 8           Frozen Foods   96.9726            OUT045
# 9           Frozen Foods  187.8214            OUT017
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
# 5                       2009      Medium               Tier 3
# 6                       1987        High               Tier 3
# 7                       1985      Medium               Tier 3
# 8                       2002         NaN               Tier 2
# 9                       2007         NaN               Tier 2
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# 5  Supermarket Type2           556.6088
# 6  Supermarket Type1           343.5528
# 7  Supermarket Type3          4022.7636
# 8  Supermarket Type1          1076.5986
# 9  Supermarket Type1          4710.5350

# %%
data.set_index('Item_Identifier', inplace=True, drop=True)

# %%
data.head(10)
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                  9.300          Low Fat         0.016047
# DRC01                  5.920          Regular         0.019278
# FDN15                 17.500          Low Fat         0.016760
# FDX07                 19.200          Regular         0.000000
# NCD19                  8.930          Low Fat         0.000000
# FDP36                 10.395          Regular         0.000000
# FDO10                 13.650          Regular         0.012741
# FDP10                    NaN          Low Fat         0.127470
# FDH17                 16.200          Regular         0.016687
# FDU28                 19.200          Regular         0.094450
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
# FDP36                     Baking Goods   51.4008            OUT018
# FDO10                      Snack Foods   57.6588            OUT013
# FDP10                      Snack Foods  107.7622            OUT027
# FDH17                     Frozen Foods   96.9726            OUT045
# FDU28                     Frozen Foods  187.8214            OUT017
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDA15                                 1999      Medium               Tier 1
# DRC01                                 2009      Medium               Tier 3
# FDN15                                 1999      Medium               Tier 1
# FDX07                                 1998         NaN               Tier 3
# NCD19                                 1987        High               Tier 3
# FDP36                                 2009      Medium               Tier 3
# FDO10                                 1987        High               Tier 3
# FDP10                                 1985      Medium               Tier 3
# FDH17                                 2002         NaN               Tier 2
# FDU28                                 2007         NaN               Tier 2
#
#                        Outlet_Type  Item_Outlet_Sales
# Item_Identifier
# FDA15            Supermarket Type1          3735.1380
# DRC01            Supermarket Type2           443.4228
# FDN15            Supermarket Type1          2097.2700
# FDX07                Grocery Store           732.3800
# NCD19            Supermarket Type1           994.7052
# FDP36            Supermarket Type2           556.6088
# FDO10            Supermarket Type1           343.5528
# FDP10            Supermarket Type3          4022.7636
# FDH17            Supermarket Type1          1076.5986
# FDU28            Supermarket Type1          4710.5350

# %%
data.loc['DRC01']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# Item_Identifier
# DRC01                   5.92          Regular         0.019278  Soft Drinks
# DRC01                   5.92          Regular         0.019309  Soft Drinks
# DRC01                    NaN          Regular         0.019107  Soft Drinks
# DRC01                   5.92          Regular         0.019239  Soft Drinks
# DRC01                   5.92          Regular         0.019200  Soft Drinks
# DRC01                   5.92          Regular         0.019184  Soft Drinks
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# DRC01             48.2692            OUT018                       2009
# DRC01             49.0692            OUT017                       2007
# DRC01             48.4692            OUT027                       1985
# DRC01             49.8692            OUT045                       2002
# DRC01             47.7692            OUT046                       1997
# DRC01             50.3692            OUT013                       1987
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# DRC01                Medium               Tier 3  Supermarket Type2
# DRC01                   NaN               Tier 2  Supermarket Type1
# DRC01                Medium               Tier 3  Supermarket Type3
# DRC01                   NaN               Tier 2  Supermarket Type1
# DRC01                 Small               Tier 1  Supermarket Type1
# DRC01                  High               Tier 3  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# DRC01                     443.4228
# DRC01                    1478.0760
# DRC01                    1034.6532
# DRC01                    1133.1916
# DRC01                     492.6920
# DRC01                     591.2304

# %%
data.loc[['DRC01', 'FDA15']]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# Item_Identifier
# DRC01                   5.92          Regular         0.019278  Soft Drinks
# DRC01                   5.92          Regular         0.019309  Soft Drinks
# DRC01                    NaN          Regular         0.019107  Soft Drinks
# DRC01                   5.92          Regular         0.019239  Soft Drinks
# DRC01                   5.92          Regular         0.019200  Soft Drinks
# DRC01                   5.92          Regular         0.019184  Soft Drinks
# FDA15                   9.30          Low Fat         0.016047        Dairy
# FDA15                   9.30          Low Fat         0.016055        Dairy
# FDA15                   9.30          Low Fat         0.016019        Dairy
# FDA15                   9.30          Low Fat         0.016088        Dairy
# FDA15                   9.30          Low Fat         0.026818        Dairy
# FDA15                   9.30          Low Fat         0.016009        Dairy
# FDA15                    NaN          Low Fat         0.015945        Dairy
# FDA15                   9.30               LF         0.016113        Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# DRC01             48.2692            OUT018                       2009
# DRC01             49.0692            OUT017                       2007
# DRC01             48.4692            OUT027                       1985
# DRC01             49.8692            OUT045                       2002
# DRC01             47.7692            OUT046                       1997
# DRC01             50.3692            OUT013                       1987
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# FDA15            248.5092            OUT035                       2004
# FDA15            249.6092            OUT018                       2009
# FDA15            248.9092            OUT010                       1998
# FDA15            250.6092            OUT013                       1987
# FDA15            249.5092            OUT027                       1985
# FDA15            248.8092            OUT017                       2007
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# DRC01                Medium               Tier 3  Supermarket Type2
# DRC01                   NaN               Tier 2  Supermarket Type1
# DRC01                Medium               Tier 3  Supermarket Type3
# DRC01                   NaN               Tier 2  Supermarket Type1
# DRC01                 Small               Tier 1  Supermarket Type1
# DRC01                  High               Tier 3  Supermarket Type1
# FDA15                Medium               Tier 1  Supermarket Type1
# FDA15                   NaN               Tier 2  Supermarket Type1
# FDA15                 Small               Tier 2  Supermarket Type1
# FDA15                Medium               Tier 3  Supermarket Type2
# FDA15                   NaN               Tier 3      Grocery Store
# FDA15                  High               Tier 3  Supermarket Type1
# FDA15                Medium               Tier 3  Supermarket Type3
# FDA15                   NaN               Tier 2  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# DRC01                     443.4228
# DRC01                    1478.0760
# DRC01                    1034.6532
# DRC01                    1133.1916
# DRC01                     492.6920
# DRC01                     591.2304
# FDA15                    3735.1380
# FDA15                    5976.2208
# FDA15                    6474.2392
# FDA15                    5976.2208
# FDA15                     498.0184
# FDA15                    6474.2392
# FDA15                    6474.2392
# FDA15                    5976.2208

# %%
data.loc[['DRC01', 'FDA15'], 'Item_Fat_Content']
# Out:
# Item_Identifier
# DRC01    Regular
# DRC01    Regular
# DRC01    Regular
# DRC01    Regular
# DRC01    Regular
# DRC01    Regular
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15         LF
# Name: Item_Fat_Content, dtype: object

# %%
sample_df = pd.DataFrame({
    'gender' : ['M', 'F', 'M', 'M', 'F'],
    'grade' : ['A', 'A', 'B', 'B', 'A'],
    'marks' : [22, 21, 12, 14, 20],
    'id' : ['A101', 'A102', 'A103', 'A104', 'A105']
})

sample_df
# Out:
#   gender grade  marks    id
# 0      M     A     22  A101
# 1      F     A     21  A102
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104

# %%
sample_df = sample_df.sort_values(by=['marks'])

sample_df
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105
# 1      F     A     21  A102
# 0      M     A     22  A101

# %%
sample_df.loc[2:4]
# Out:
#   gender grade  marks    id
# 2      M     B     12  A103
# 3      M     B     14  A104
# 4      F     A     20  A105

# %%
sample_df.iloc[2:4]
# Out:
#   gender grade  marks    id
# 4      F     A     20  A105
# 1      F     A     21  A102

# %%
sample_df.set_index('id', inplace=True)

# %%
sample_df
# Out:
#      gender grade  marks
# id
# A103      M     B     12
# A104      M     B     14
# A105      F     A     20
# A102      F     A     21
# A101      M     A     22

# %%
sample_df.iloc[2:4]
# Out:
#      gender grade  marks
# id
# A105      F     A     20
# A102      F     A     21

# %%
sample_df.loc['A103' : 'A104']
# Out:
#      gender grade  marks
# id
# A103      M     B     12
# A104      M     B     14
